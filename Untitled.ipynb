# %%
import pandas as pd

# %%
pd.read_pickle('inter_log_res_save.pickle')
# Out:
#      time_serie  product_labels         error          aic        pdq  \
# 0      bookings               0  7.646525e+00 -1354.467789  (0, 0, 0)
# 1      bookings               0  8.237985e+00 -2034.767685  (0, 0, 1)
# 2      bookings               0  1.032756e+01 -3234.270443  (0, 1, 0)
# 3      bookings               0  1.027581e+01 -3252.072196  (0, 1, 1)
# 4      bookings               0  3.206825e+01 -2068.000243  (0, 2, 0)
# 5      bookings               0  5.699554e+00 -3219.999169  (0, 2, 1)
# 6      bookings               0  1.405787e+01 -3233.786151  (1, 0, 0)
# 7      bookings               0  1.289513e+01 -3251.339305  (1, 0, 1)
# 8      bookings               0  1.030721e+01 -3251.179271  (1, 1, 0)
# 9      bookings               0  1.039349e+01 -3291.761737  (1, 1, 1)
# 10     bookings               0  3.234091e+01 -2522.087614  (1, 2, 0)
# 11     bookings               0  5.738665e+00 -3236.353761  (1, 2, 1)
# ...
