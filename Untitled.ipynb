# %%
1+1
# Out:
# 2

# %%
import pandas as pd

# %%
pd.read_pickle('inter_log_res_save.pickle')
# Out:
#      time_serie  product_labels         error          aic        pdq  \
# 0      bookings               0  6.251590e+02  6846.304797  (0, 0, 0)
# 1      bookings               0  6.250631e+02  4895.972677  (0, 0, 1)
# 2      bookings               0  2.035288e+02 -3128.543538  (0, 1, 0)
# 3      bookings               0  2.016261e+02 -3152.250759  (0, 1, 1)
# 4      bookings               0  6.157214e+02 -1940.409699  (0, 2, 0)
# 5      bookings               0  1.181089e+02 -3114.535701  (0, 2, 1)
# 6      bookings               0  2.382193e+02 -3129.710349  (1, 0, 0)
# 7      bookings               0  1.942185e+02 -3153.269443  (1, 0, 1)
# 8      bookings               0  2.023403e+02 -3150.313388  (1, 1, 0)
# 9      bookings               0  2.042794e+02 -3194.113317  (1, 1, 1)
# 10     bookings               0  6.202543e+02 -2410.759183  (1, 2, 0)
# 11     bookings               0  1.168584e+02 -3135.802068  (1, 2, 1)
# ...
