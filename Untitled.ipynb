# %%
1+1
# Out:
# 2

# %%
import pandas as pd

# %%
pd.read_pickle('inter_res_save_exog.pickle')
# Out:
#     time_serie  product_labels       error          aic        pdq  \
# 0     bookings               0   10.500166  6976.969645  (0, 0, 0)
# 1     bookings               1   10.404230  6643.494152  (0, 0, 0)
# 2     bookings               2   17.665344  7783.063722  (0, 0, 0)
# 3     sessions               0  255.822515  5009.943053  (0, 0, 0)
# 4     sessions               1  209.004100  4843.317376  (0, 0, 0)
# 5     sessions               2  274.329607  5039.935557  (0, 0, 0)
# 6     bookings               0   11.869265  5934.991216  (0, 0, 0)
# 7     bookings               1   10.960990  5921.524896  (0, 0, 0)
# 8     bookings               2   19.477635  6539.934249  (0, 0, 0)
# 9     sessions               0  294.724676  4837.351332  (0, 0, 0)
# 10    sessions               1  207.594709  4808.217881  (0, 0, 0)
# 11    sessions               2  291.486192  4936.559874  (0, 0, 0)
# 12    bookings               0    9.693528  6038.086413  (0, 0, 0)
# ...
